# %% [markdown]
# # **Tarea 2**
#
# Nombre: Reyes Avila David.
#
# No. Cuenta: 316184979
#
# Email: david.reyes.avila.fic@comunidad.unam.mx

# %% [markdown]
# ###
# **Objetivo:** Encontrar información de interés.
#
#
# **Fuente de datos**
# Recopilación de datos de partidos de la NBA de la temporada regular desde 2004 hasta 2022.

# %% [markdown]
# ### **Importar las bibliotecas y los datos**

# %%
import pandas as pd               # Para la manipulación y análisis de datos
import numpy as np                # Para crear vectores y matrices n dimensionales
import matplotlib.pyplot as plt   # Para la generación de gráficas a partir de los datos
import seaborn as sns             # Para la visualización de datos basado en matplotlib
# %matplotlib inline                
# Para generar y almacenar los gráficos dentro del cuaderno

# %%
URL2="https://github.com/David-RA316184979/Mineria_DRA/blob/main/Datos/games.csv?raw=true"
DatosNBA = pd.read_csv(URL2, delimiter=",",index_col=0) #datos de la NBA
DatosNBA
# Out:
#                 GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# GAME_DATE_EST
# 2022-03-12     22101005            Final    1610612748       1610612750
# 2022-03-12     22101006            Final    1610612741       1610612739
# 2022-03-12     22101007            Final    1610612759       1610612754
# 2022-03-12     22101008            Final    1610612744       1610612749
# 2022-03-12     22101009            Final    1610612743       1610612761
# ...                 ...              ...           ...              ...
# 2014-10-06     11400007            Final    1610612737       1610612740
# 2014-10-06     11400004            Final    1610612741       1610612764
# 2014-10-06     11400005            Final    1610612747       1610612743
# 2014-10-05     11400002            Final    1610612761       1610612758
# 2014-10-04     11400001            Final    1610612748       1610612740
#
#                SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  \
# GAME_DATE_EST
# 2022-03-12       2021    1610612748     104.0        0.398        0.760
# 2022-03-12       2021    1610612741     101.0        0.443        0.933
# 2022-03-12       2021    1610612759     108.0        0.412        0.813
# 2022-03-12       2021    1610612744     122.0        0.484        0.933
# 2022-03-12       2021    1610612743     115.0        0.551        0.750
# ...               ...           ...       ...          ...          ...
# 2014-10-06       2014    1610612737      93.0        0.419        0.821
# 2014-10-06       2014    1610612741      81.0        0.338        0.719
# 2014-10-06       2014    1610612747      98.0        0.448        0.682
# 2014-10-05       2014    1610612761      99.0        0.440        0.771
# 2014-10-04       2014    1610612748      86.0        0.431        0.679
#
#                FG3_PCT_home  AST_home  REB_home  TEAM_ID_away  PTS_away  \
# GAME_DATE_EST
# 2022-03-12            0.333      23.0      53.0    1610612750     113.0
# 2022-03-12            0.429      20.0      46.0    1610612739      91.0
# 2022-03-12            0.324      28.0      52.0    1610612754     119.0
# 2022-03-12            0.400      33.0      55.0    1610612749     109.0
# 2022-03-12            0.407      32.0      39.0    1610612761     127.0
# ...                     ...       ...       ...           ...       ...
# 2014-10-06            0.421      24.0      50.0    1610612740      87.0
# 2014-10-06            0.381      18.0      40.0    1610612764      85.0
# 2014-10-06            0.500      29.0      45.0    1610612743      95.0
# 2014-10-05            0.333      21.0      30.0    1610612758      94.0
# 2014-10-04            0.333      18.0      42.0    1610612740      98.0
#
#                FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away  REB_away  \
# 2014-10-07                  1
# 2014-10-07                  1
# 2014-10-07                  0
# 2014-10-06                  1
# 2014-10-06                  1
# 2014-10-06                  0
# 2014-10-06                  1
# 2014-10-05                  1
# 2014-10-04                  0

# %% [markdown]
# ### **Paso 1: Descripción de la estructura de los datos**
#
# 1) Forma (dimensiones) del DataFrame
#
# El atributo .shape de Pandas proporciona una estructura general de los datos. Devuelve la cantidad de filas y columnas que tiene el conjunto de datos.

# %%
DatosNBA.shape
# Out:
# (25796, 20)

# %% [markdown]
# 2) Tipos de datos (variables)
#
# El atributo .dtypes muestra los tipos de datos de las columnas (variables y tipos).

# %%
DatosNBA.dtypes
# Out:
# GAME_ID               int64
# GAME_STATUS_TEXT     object
# HOME_TEAM_ID          int64
# VISITOR_TEAM_ID       int64
# SEASON                int64
# TEAM_ID_home          int64
# PTS_home            float64
# FG_PCT_home         float64
# FT_PCT_home         float64
# FG3_PCT_home        float64
# AST_home            float64
# REB_home            float64
# TEAM_ID_away          int64
# PTS_away            float64
# FG_PCT_away         float64
# FT_PCT_away         float64
# FG3_PCT_away        float64
# AST_away            float64
# REB_away            float64
# HOME_TEAM_WINS        int64
# dtype: object

# %% [markdown]
# Se observa que el conjunto de datos tiene una combinación de variables categóricas (objeto) y numéricas (flotante e int).

# %% [markdown]
# ### **Paso 2: Identificación de datos faltantes**
#
# Una función útil de pandas es **.isnull().sum()** que regresa la suma de todos los valores nulos en cada variable.

# %%
DatosNBA.isnull().sum()
# Out:
# GAME_ID              0
# GAME_STATUS_TEXT     0
# HOME_TEAM_ID         0
# VISITOR_TEAM_ID      0
# SEASON               0
# TEAM_ID_home         0
# PTS_home            99
# FG_PCT_home         99
# FT_PCT_home         99
# FG3_PCT_home        99
# AST_home            99
# REB_home            99
# TEAM_ID_away         0
# PTS_away            99
# FG_PCT_away         99
# FT_PCT_away         99
# FG3_PCT_away        99
# AST_away            99
# REB_away            99
# HOME_TEAM_WINS       0
# dtype: int64

# %% [markdown]
# También se puede usar **info()** para obtener el tipo de datos y la suma de valores nulos.

# %%
DatosNBA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25796 entries, 2022-03-12 to 2014-10-04
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GAME_ID           25796 non-null  int64
#  1   GAME_STATUS_TEXT  25796 non-null  object
#  2   HOME_TEAM_ID      25796 non-null  int64
#  3   VISITOR_TEAM_ID   25796 non-null  int64
#  4   SEASON            25796 non-null  int64
#  5   TEAM_ID_home      25796 non-null  int64
#  6   PTS_home          25697 non-null  float64
#  7   FG_PCT_home       25697 non-null  float64
#  8   FT_PCT_home       25697 non-null  float64
#  9   FG3_PCT_home      25697 non-null  float64
#  10  AST_home          25697 non-null  float64
#  11  REB_home          25697 non-null  float64
#  12  TEAM_ID_away      25796 non-null  int64
#  13  PTS_away          25697 non-null  float64
#  14  FG_PCT_away       25697 non-null  float64
#  15  FT_PCT_away       25697 non-null  float64
#  16  FG3_PCT_away      25697 non-null  float64
#  17  AST_away          25697 non-null  float64
#  18  REB_away          25697 non-null  float64
#  19  HOME_TEAM_WINS    25796 non-null  int64
# dtypes: float64(12), int64(7), object(1)
# memory usage: 4.1+ MB

# %% [markdown]
# ### **Paso 3: Detección de valores atípicos**
#
# Se pueden utilizar gráficos para tener una idea general de las distribuciones de los datos, y se sacan estadísticas para resumir los datos. Estas dos estrategias son recomendables y se complementan.
#
# La distribución se refiere a cómo se distribuyen los valores en una variable o con qué frecuencia ocurren.
#
# Para las variables numéricas, se observa cuántas veces aparecen grupos de números en una columna. Mientras que para las variables categóricas, son las clases de cada columna y su frecuencia.

# %% [markdown]
# **1) Distribución de variables numéricas**
#
# * Se utilizan histogramas que agrupan los números en rangos.
# * La altura de una barra muestra cuántos números caen en ese rango.
# * Se emplea **hist()** para trazar el histograma de las variables numéricas. También se pueden usar los parámetros: **figsize** y **xrot** para aumentar el tamaño de la cuadrícula y rotar el eje x 45 grados.

# %%
DatosNBA.hist(figsize=(14,14), xrot=45)
plt.show()

# %% [markdown]
# **Qué buscar:**
#
# * Posibles valores atípicos, que pueden ser errores de medición.
# * Límites que no tienen sentido, como valores porcentuales > 100.

# %% [markdown]
# **2) Resumen estadístico de variables numéricas**
#
# Se sacan estadísticas usando **describe()** que muestra un resumen estadístico de las variables numéricas.

# %%
DatosNBA.describe()
# Out:
#             GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID        SEASON  \
# count  2.579600e+04  2.579600e+04     2.579600e+04  25796.000000
# mean   2.169208e+07  1.610613e+09     1.610613e+09   2011.798341
# std    5.496041e+06  8.638857e+00     8.654846e+00      5.397985
# min    1.030000e+07  1.610613e+09     1.610613e+09   2003.000000
# 25%    2.060109e+07  1.610613e+09     1.610613e+09   2007.000000
# 50%    2.120040e+07  1.610613e+09     1.610613e+09   2012.000000
# 75%    2.170070e+07  1.610613e+09     1.610613e+09   2016.000000
# max    5.200021e+07  1.610613e+09     1.610613e+09   2021.000000
#
#        TEAM_ID_home      PTS_home   FG_PCT_home   FT_PCT_home  FG3_PCT_home  \
# count  2.579600e+04  25697.000000  25697.000000  25697.000000  25697.000000
# mean   1.610613e+09    103.106044      0.460313      0.759705      0.355896
# std    8.638857e+00     13.174726      0.056629      0.100692      0.111940
# min    1.610613e+09     36.000000      0.250000      0.143000      0.000000
# 25%    1.610613e+09     94.000000      0.421000      0.696000      0.286000
# 50%    1.610613e+09    103.000000      0.459000      0.765000      0.355000
# 75%    1.610613e+09    112.000000      0.500000      0.829000      0.429000
# max    1.610613e+09    168.000000      0.684000      1.000000      1.000000
#
#            AST_home      REB_home  TEAM_ID_away      PTS_away   FG_PCT_away  \
# count  25697.000000  25697.000000  2.579600e+04  25697.000000  25697.000000
# mean      22.736779     43.345799  1.610613e+09    100.294120      0.449265
# std        5.177566      6.621832  8.654846e+00     13.343016      0.055528
# min        6.000000     15.000000  1.610613e+09     33.000000      0.244000
# 25%       19.000000     39.000000  1.610613e+09     91.000000      0.412000
# 50%       23.000000     43.000000  1.610613e+09    100.000000      0.448000
# 75%       26.000000     48.000000  1.610613e+09    109.000000      0.487000
# max       50.000000     72.000000  1.610613e+09    168.000000      0.687000
#
#         FT_PCT_away  FG3_PCT_away      AST_away      REB_away  HOME_TEAM_WINS
# count  25697.000000  25697.000000  25697.000000  25697.000000    25796.000000
# mean       0.758082      0.349413     21.403899     42.085146        0.587494
# std        0.103418      0.110194      5.140897      6.526951        0.492295
# min        0.143000      0.000000      4.000000     19.000000        0.000000
# 25%        0.692000      0.278000     18.000000     38.000000        0.000000
# 50%        0.765000      0.350000     21.000000     42.000000        1.000000
# 75%        0.833000      0.420000     25.000000     46.000000        1.000000
# max        1.000000      1.000000     46.000000     81.000000        1.000000

# %% [markdown]
# * Se incluye un recuento, media, desviación, valor mínimo, valor máximo, percentil inferior (25%), 50% y percentil superior (75%).
# * Por defecto, el percentil 50 es lo mismo que la mediana.
# * Se observa que para cada variable, el recuento también ayuda a identificar variables con valores perdidos.

# %% [markdown]
# **3) Diagramas para detectar posibles valores atípicos**
#
# Para este tipo de gráficos se utiliza **Seaborn**, que permite generar diagramas de cajas para detectar valores atípicos.

# %%
VariablesValoresAtipicos = ['GAME_ID', 'FG_PCT_home', 'FG3_PCT_home', 'FG_PCT_away', 'FG3_PCT_away']
for col in VariablesValoresAtipicos:
  sns.boxplot(col, data=DatosNBA)
  plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Se observa que GAME_ID, FG3_PCT_home y FG3_PCT_away tienen valores atípicos que están lejos de los otros valores.

# %% [markdown]
# **4) Distribución de variables categóricas**
#
# Se refiere a la observación de las clases de cada columna (variable) y su frecuencia. Aquí, los gráficos ayudan para tener una idea general de las distribuciones, mientras que las estadísticas dan números reales.

# %%
DatosNBA.describe(include='object')
# Out:
#        GAME_STATUS_TEXT
# count             25796
# unique                1
# top               Final
# freq              25796

# %% [markdown]
# * Esta tabla es diferente al de los valores numéricos. Aquí, se obtiene el recuento de los valores de cada variable, el número de clases únicas, la clase más frecuente y con qué frecuencia ocurre esa clase en el conjunto de datos.

# %% [markdown]
# **Plot**
#
# * Para este tipo de gráficos se utiliza Seaborn, que permite generar un histograma para variables categóricas. Cada barra en el gráfico de conteo representa una clase.
# * Se crea un bucle para el conteo y distribución de las clases. La sentencia select_dtypes(include = ’object’) selecciona las columnas categóricas con sus valores y las muestra.
# * Se incluye también If para elegir solo las tres columnas con 10 o menos clases usando series.**nunique() < 10**.

# %%
for col in DatosNBA.select_dtypes(include='object'):
  if DatosNBA[col].nunique()<10:sns.countplot(y=col, data=DatosNBA)
  plt.show()

# %% [markdown]
# **5) Agrupación por variables categóricas**

# %%
for col in DatosNBA.select_dtypes(include='object'):
  if DatosNBA[col].nunique() < 10:
    display(DatosNBA.groupby(col).agg(['mean']))
# Out:
#                        GAME_ID  HOME_TEAM_ID VISITOR_TEAM_ID       SEASON  \
#                           mean          mean            mean         mean
# GAME_STATUS_TEXT
# Final             2.169208e+07  1.610613e+09    1.610613e+09  2011.798341
#
#                   TEAM_ID_home    PTS_home FG_PCT_home FT_PCT_home  \
#                           mean        mean        mean        mean
# GAME_STATUS_TEXT
# Final             1.610613e+09  103.106044    0.460313    0.759705
#
#                  FG3_PCT_home   AST_home   REB_home  TEAM_ID_away   PTS_away  \
#                          mean       mean       mean          mean       mean
# GAME_STATUS_TEXT
# Final                0.355896  22.736779  43.345799  1.610613e+09  100.29412
#
#                  FG_PCT_away FT_PCT_away FG3_PCT_away   AST_away   REB_away  \
#                         mean        mean         mean       mean       mean
# GAME_STATUS_TEXT
# Final               0.449265    0.758082     0.349413  21.403899  42.085146
#
#                  HOME_TEAM_WINS
#                            mean
# GAME_STATUS_TEXT
# Final                  0.587494

# %% [markdown]
# ### **Paso 4: Identificación de relaciones entre pares variables**
#
# Una matriz de correlaciones es útil para analizar la relación entre las variables numéricas.
# Se emplea la función corr()

# %%
DatosNBA.corr()
# Out:
#                   GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_
# TEAM_ID_away         0.017292  0.018287 -0.002759      1.000000 -0.032583
# PTS_away             0.046740  0.183636 -0.152464     -0.032583  1.000000
# FG_PCT_away          0.008265  0.006043 -0.474556     -0.026651  0.669054
# FT_PCT_away          0.015199  0.026035 -0.115795     -0.018476  0.201684
# FG3_PCT_away        -0.001993 -0.006692 -0.205682     -0.022625  0.409656
# AST_away            -0.002371  0.142278 -0.100354     -0.013180  0.591523
# REB_away            -0.201855 -0.108505  0.068494     -0.010262  0.176835
# HOME_TEAM_WINS       0.300804  0.303889  0.246358      0.030571 -0.415491
#
#                  FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away  REB_away  \
# GAME_ID             0.005716     0.033366     -0.002642 -0.042501 -0.024355
# HOME_TEAM_ID        0.022197     0.016042      0.015525 -0.066744 -0.025784
# VISITOR_TEAM_ID    -0.026651    -0.018476     -0.022625 -0.013180 -0.010262
# SEASON              0.073299     0.066808      0.020564  0.255330  0.199832
# TEAM_ID_home        0.022197     0.016042      0.015525 -0.066744 -0.025784
# PTS_home            0.128207     0.069504      0.057260  0.208445 -0.139219
# FG_PCT_home         0.039905     0.030386      0.014223  0.013061 -0.464576
# FT_PCT_home         0.046824     0.036861      0.021528  0.029812 -0.115124
# FG3_PCT_home        0.008265     0.015199     -0.001993 -0.002371 -0.201855
# AST_home            0.006043     0.026035     -0.006692  0.142278 -0.108505
# REB_home           -0.474556    -0.115795     -0.205682 -0.100354  0.068494
# TEAM_ID_away       -0.026651    -0.018476     -0.022625 -0.013180 -0.010262
# PTS_away            0.669054     0.201684      0.409656  0.591523  0.176835
# FG_PCT_away         1.000000     0.038309      0.435279  0.524138 -0.171026
# FT_PCT_away         0.038309     1.000000      0.031278  0.029563 -0.038057
# FG3_PCT_away        0.435279     0.031278      1.000000  0.320075 -0.094666
# AST_away            0.524138     0.029563      0.320075  1.000000  0.071461
# REB_away           -0.171026    -0.038057     -0.094666  0.071461  1.000000
# HOME_TEAM_WINS     -0.436616    -0.106917     -0.290396 -0.294976 -0.253673
#
#                  HOME_TEAM_WINS
# GAME_ID                0.030402
# HOME_TEAM_ID          -0.023604
# VISITOR_TEAM_ID        0.030571
# SEASON                -0.028197
# TEAM_ID_home          -0.023604
# PTS_home               0.398901
# FG_PCT_home            0.433626
# FT_PCT_home            0.092710
# FG3_PCT_home           0.300804
# AST_home               0.303889
# REB_home               0.246358
# TEAM_ID_away           0.030571
# PTS_away              -0.415491
# FG_PCT_away           -0.436616
# FT_PCT_away           -0.106917
# FG3_PCT_away          -0.290396
# AST_away              -0.294976
# REB_away              -0.253673
# HOME_TEAM_WINS         1.000000

# %%
plt.figure(figsize=(14,7))
sns.heatmap(DatosNBA.corr(), cmap='RdBu_r', annot=True)
plt.show()

# %%
plt.figure(figsize=(14,7))
MatrizInf = np.triu(DatosMelbourne.corr())
sns.heatmap(DatosMelbourne.corr(), cmap='RdBu_r', annot=True, mask=MatrizInf)
plt.show()

# %% [markdown]
# * Una correlación es un valor entre -1 y 1 que equivale a qué tan cerca se mueven simultáneamente los valores de dos variables.
# * Una correlación positiva significa que a medida que una característica aumenta, la otra también aumenta.
# * Una correlación negativa significa que a medida que una característica disminuye, la otra también disminuye.
# * Las correlaciones cercanas a 0 indican una relación débil, mientras que las más cercanas a -1 o 1 significan una relación fuerte.
